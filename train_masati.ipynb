# %% [markdown]
# Following steps from https://github.com/ultralytics/yolov3/issues/1570

# %%
# !python train.py --img-size 512 --batch 16 --epochs 5 --data masati.yaml --weights yolov3.pt --workers 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='', data='./data/masati.yaml', device='', epochs=5, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[512, 512], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/exp2', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov3.pt', workers=0, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-12-02 11:30:42.959318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-12-02 11:30:42.961735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# ...

# %% [markdown]
# ### trying with yolov5...

# %%
# !python train.py --img 512 --batch 8 --epochs 5 --data masati.yaml --weights yolov5s.pt
# Out:
# Traceback (most recent call last):
#   File "train.py", line 19, in <module>
#     from torch.cuda import amp
# ImportError: cannot import name 'amp'

# %%
 import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0 _CudaDeviceProperties(name='Tesla V100-PCIE-16GB', major=7, minor=0, total_memory=16160MB, multi_processor_count=80)

# %%
# !python test.py --weights yolov5s.pt --data masati.yaml --img 512 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/masati.yaml', device='', exist_ok=False, img_size=512, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5s.pt'])
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Killed

# %%
# !python3.8 -m pip install ipykernel
# Out:
# ...
#      |████████████████████████████████| 120 kB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 784 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.4 MB 5.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 108 kB 8.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 3.6 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 109 kB 8.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 59 kB 7.4 MB/s eta 0:00:011
# ...
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# ...
#      |████████████████████████████████| 355 kB 6.0 MB/s eta 0:00:01
# ...
#   Using cached ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# ...
#      |████████████████████████████████| 948 kB 8.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 9.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 427 kB 9.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 100 kB 11.2 MB/s ta 0:00:01
# ...

# %% [markdown]
# ## Ran successfully 50 epochs of training. Results look good (in runs/train/exp8...)

# %%
# !python3.8 train.py --img 512 --batch 8 --epochs 50 --data masati.yaml --weights yolov5x.pt --workers 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=False, cfg='', data='./data/masati.yaml', device='', epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[512, 512], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/exp8', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolov5x.pt', workers=0, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %% [markdown]
# ### Now give it *another* 50 epochs, starting from the same weights we got out of the previous 50 epochs training

# %%
# !python3.8 train.py --img 512 --batch 16 --epochs 50 --data masati.yaml --weights weights/masati_yolov5x_50epoch_training.pt --workers 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='', data='./data/masati.yaml', device='', epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[512, 512], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/exp9', single_cls=False, sync_bn=False, total_batch_size=16, weights='weights/masati_yolov5x_50epoch_training.pt', workers=0, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
import tensorboard

# %%
tensorboard --logdir=runs
# Out:
#   File "<ipython-input-9-8dfe2aebc706>", line 1
#     tensorboard --logdir=runs
#                              ^
# SyntaxError: can't assign to operator
