# %% [markdown]
# Following steps from https://github.com/ultralytics/yolov3/issues/1570

# %% [markdown]
# ### trying with yolov5...

# %%
# !python3.8 train.py --help
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE]
#                 [--img-size IMG_SIZE [IMG_SIZE ...]] [--rect]
#                 [--resume [RESUME]] [--nosave] [--notest] [--noautoanchor]
#                 [--evolve] [--bucket BUCKET] [--cache-images]
#                 [--image-weights] [--device DEVICE] [--multi-scale]
#                 [--single-cls] [--adam] [--sync-bn] [--local_rank LOCAL_RANK]
#                 [--log-imgs LOG_IMGS] [--workers WORKERS] [--project PROJECT]
#                 [--name NAME] [--exist-ok]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --weights WEIGHTS     initial weights path
#   --cfg CFG             model.yaml path
#   --data DATA           data.yaml path
#   --hyp HYP             hyperparameters path
#   --epochs EPOCHS
#   --batch-size BATCH_SIZE
#                         total batch size for all GPUs
# ...

# %%
# !python3.8 train.py --img 1175 --rect --batch 2 --epochs 50 --data sassoon.yaml --weights weights/masati_yolov5x_100epoch_best.pt --workers 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=2, bucket='', cache_images=False, cfg='', data='./data/sassoon.yaml', device='', epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1175, 1175], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=True, resume=False, save_dir='runs/train/exp11', single_cls=False, sync_bn=False, total_batch_size=2, weights='weights/masati_yolov5x_100epoch_best.pt', workers=0, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %% [markdown]
# The run below corresponds to exp12:

# %%
# !python3.8 train.py --img 1175 --rect --batch 2 --epochs 100 --data sassoon.yaml --weights runs/train/exp11/weights/best.pt --workers 0
# Out:
# /bin/sh: 1: python3.8: not found

# %% [markdown]
# Didn't think results were great, so I added a *lot* more labelled sassoon data. Gone from 7 train imgs/2 validation to 49 train images, 17 validation

# %%
# !python3.8 train.py --img 1175 --rect --batch 2 --epochs 100 --data sassoon.yaml --weights weights/masati_yolov5x_100epoch_best.pt --workers 0
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=2, bucket='', cache_images=False, cfg='', data='./data/sassoon.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1175, 1175], local_rank=-1, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=True, resume=False, save_dir='runs/train/exp13', single_cls=False, sync_bn=False, total_batch_size=2, weights='weights/masati_yolov5x_100epoch_best.pt', workers=0, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %% [markdown]
# Extra runs with wandb

# %%
# !python3.8 -m pip install ipykernel

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 1 --single-cls --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 1 --single-cls --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0 --adam
# Out:
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# ...

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 20 --single-cls --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0
# Out:
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# ...

# %% [markdown]
# This run (exp20) got the best results according to wandb

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 20 --single-cls --hyp data/hyp.sassoon.yaml --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0
# Out:
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# ...

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 20 --single-cls --hyp data/hyp.sassoon.yaml --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0
# Out:
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# ...

# %% [markdown]
# Run exp20 again without the single_cls arg

# %%
# !python3.8 train.py --img 1175 --rect --batch 8 --epochs 50 --hyp data/hyp.sassoon.yaml --data sassoon.yaml --weights weights/sassoon100epoch_best_trained_on_masati_yolov5x_100epoch.pt --workers 0
# Out:
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# ...
