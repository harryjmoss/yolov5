# %% [markdown]
# Following steps from https://github.com/ultralytics/yolov3/issues/1570

# %% [markdown]
# This run (exp20) got the best results according to wandb

# %%
 # !python3.8 detect.py --weights weights/sassoon_wandb_best_120epoch_trained_on_masati100epoch_yolov5x.pt --img 1175 --conf 0.25 --source data/images/sassoon
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=1175, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/sassoon', update=False, view_img=False, weights=['weights/sassoon_wandb_best_120epoch_trained_on_masati100epoch_yolov5x.pt'])
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# Fusing layers...
# Model Summary: 484 layers, 88390614 parameters, 0 gradients
# WARNING: --img-size 1175 must be multiple of max stride 32, updating to 1184
# ...

# %%
# !python3.8 detect.py --weights weights/sassoon_wandb_best_120epoch_trained_on_masati100epoch_yolov5x.pt --img 1175 --conf 0.25 --source data/images/sassoon --iou-thres 0.5 --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=1175, iou_thres=0.5, name='exp', project='runs/detect', save_conf=False, save_txt=True, source='data/images/sassoon', update=False, view_img=False, weights=['weights/sassoon_wandb_best_120epoch_trained_on_masati100epoch_yolov5x.pt'])
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# Fusing layers...
# Model Summary: 484 layers, 88390614 parameters, 0 gradients
# WARNING: --img-size 1175 must be multiple of max stride 32, updating to 1184
# ...

# %%
# !python3.8 detect.py --weights weights/sasoon_10_12_2020.pt --img 1175 --conf 0.25 --source data/images/sassoon --iou-thres 0.5 --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=1175, iou_thres=0.5, name='exp', project='runs/detect', save_conf=False, save_txt=True, source='data/images/sassoon', update=False, view_img=False, weights=['weights/sasoon_10_12_2020.pt'])
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# Fusing layers...
# Model Summary: 484 layers, 88390614 parameters, 0 gradients
# WARNING: --img-size 1175 must be multiple of max stride 32, updating to 1184
# ...

# %%
# !python3.8 detect.py --weights weights/sasoon_10_12_2020.pt --img 1175 --conf 0.25 --source data/images/sassoon --iou-thres 0.5 --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=1175, iou_thres=0.5, name='exp', project='runs/detect', save_conf=False, save_txt=True, source='data/images/sassoon', update=False, view_img=False, weights=['weights/sasoon_10_12_2020.pt'])
# Using torch 1.7.1 CUDA:0 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:1 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:2 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:3 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:4 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:5 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:6 (Tesla V100-SXM2-32GB, 32510MB)
#                   CUDA:7 (Tesla V100-SXM2-32GB, 32510MB)
#
# Fusing layers...
# Model Summary: 484 layers, 88390614 parameters, 0 gradients
# WARNING: --img-size 1175 must be multiple of max stride 32, updating to 1184
# ...
